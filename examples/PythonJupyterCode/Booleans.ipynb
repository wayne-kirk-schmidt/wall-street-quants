# %% [markdown]
# # Booleans
# 1. Used in loops & if/else statements
# 2. Used for indexing arrays

# %%
a=True
b=False

print (a)
print (b)
# Out:
# True
# False

# %%
print (type(a))
print (type(b))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
# generating booleans using operators on numbers
x = 2
y = 3

print (x==y) # equal
print (x!=y) # not equal
print (x>y) # greater than
print (x<y) # less than
print (x>=y) # greater than or equal to
print (x<=y) # less than or equal to
# Out:
# False
# True
# False
# True
# False
# True

# %%
# generating booleans using operators on strings
x = 'TSLA US Equity'
y = 'AAPL US Equity'

print ('TSLA' in x)
print (x==y)
print (x!=y)
# Out:
# True
# False
# True

# %%
# logical operators
x = 3

print (x<10 and x>5)
print (not(x<10 and x>5))
print (x<10 or x>5)
# Out:
# False
# True
# True

# %%
print(help(x != y), bit_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(help(bit_count))
#
# NameError: name 'bit_count' is not defined
