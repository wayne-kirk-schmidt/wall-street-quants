# %% [markdown]
# # Lists

# %%
# create a list using square brackets
stocks = ['AAPL','BAC','XOM','LULU']
print (stocks)
print (type(stocks))
# Out:
# ['AAPL', 'BAC', 'XOM', 'LULU']
# <class 'list'>

# %%
# lists can be of any data type
returns = [0.01,-0.01,0.02,0.03]
print (returns)
print (type(returns))
# Out:
# [0.01, -0.01, 0.02, 0.03]
# <class 'list'>

# %%
# Retrieving values

# positive indexing
print (stocks[0])
print (stocks[2])
print (stocks[3])
# Out:
# AAPL
# XOM
# LULU

# %%
# Negative indexing
print (stocks[-1])
print (stocks[-2])
print (stocks[-4])
# Out:
# LULU
# XOM
# AAPL

# %%
# Index Range w/ Positives
print (stocks[1:3])
print (stocks[:4])
print (stocks[2:])
# Out:
# ['BAC', 'XOM']
# ['AAPL', 'BAC', 'XOM', 'LULU']
# ['XOM', 'LULU']

# %%
# Index Range w/ Negatives
print (stocks[-3:-1])
print (stocks[-3:])
print (stocks[:-2])
# Out:
# ['BAC', 'XOM']
# ['BAC', 'XOM', 'LULU']
# ['AAPL', 'BAC']

# %%
# check if an item exists 
print ('TSLA' in stocks) 
print ('AAPL' in stocks)
# Out:
# False
# True

# %%
# changing values
stocks[0]='MSFT'
print (stocks)

# inserting values
stocks.insert(1,'AAPL')
print (stocks)
# Out:
# ['MSFT', 'BAC', 'XOM', 'LULU']
# ['MSFT', 'AAPL', 'BAC', 'XOM', 'LULU']

# %%
stocks.append('TWTR')
print (stocks)
# Out:
# ['MSFT', 'AAPL', 'BAC', 'XOM', 'LULU', 'TWTR']

# %%
stocks.remove('AAPL')
print (stocks)
# Out:
# ['MSFT', 'BAC', 'XOM', 'LULU', 'TWTR']

# %%
stocks.pop()
print (stocks)
# Out:
# ['MSFT', 'BAC', 'XOM', 'LULU']

# %%
# combining lists
tech = ['AAPL','MSFT','FB']
fin = ['BAC','JPM','GS']
both = tech + fin
print (both)
# Out:
# ['AAPL', 'MSFT', 'FB', 'BAC', 'JPM', 'GS']

# %%
# tab completion
both.sort()
both
# Out:
# ['AAPL', 'BAC', 'FB', 'GS', 'JPM', 'MSFT']

# %%
both.sort?
# Out:
# Signature: both.sort(*, key=None, reverse=False)
# Docstring:
# Sort the list in ascending order and return None.
#
# The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
# order of two equal elements is maintained).
#
# If a key function is given, apply it once to each list item and sort them,
# ascending or descending, according to their function values.
#
# The reverse flag can be set to sort in descending order.
# Type:      builtin_function_or_method

# %%
both.sort(key=toupper,reverse=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 both.sort(key=toupper,reverse=True)
#
# NameError: name 'toupper' is not defined

# %%
both
# Out:
# ['MSFT', 'JPM', 'GS', 'FB', 'BAC', 'AAPL']
