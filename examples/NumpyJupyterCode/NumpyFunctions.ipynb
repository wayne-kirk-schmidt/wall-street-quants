# %% [markdown]
# # Numpy Functions
# 1. Universal functions
# 2. Data analysis functions

# %% [markdown]
# ## Universal Functions
# - Function that performs elementwise operations on data in arrays

# %%
import numpy as np

# many ufuncs operate on a single array
arr = np.array([1,4,9,16])
np.sqrt(arr)
# Out:
# array([1., 2., 3., 4.])

# %%
np.log(arr)
# Out:
# array([0.        , 1.38629436, 2.19722458, 2.77258872])

# %%
# some ufuncs operate on multiple arrays 
arr1=np.array([1,-1,3,5])
arr2=np.array([2,1,4,1])
np.maximum(arr1,arr2)
# Out:
# array([2, 1, 4, 5])

# %% [markdown]
# ![Screen%20Shot%202021-10-17%20at%206.43.42%20PM.png](attachment:Screen%20Shot%202021-10-17%20at%206.43.42%20PM.png)

# %% [markdown]
# ## Data Analysis
# 1. Math/Stat Methods
# 2. Boolean Array Operations
# 3. Sorting/Unique Values
#
# ### Math/Stat Methods

# %%
list1 = [1,1.1,-5.45,3.2]
arr1 = np.array(list1)

list2 = [[1,1.1,-5.45,3.2],[-0.5,0.33,10.12,-5]]
arr2 = np.array(list2)

# %%
# arrays have many built in functions that aggregate the data 
arr1.mean()
# Out:
# np.float64(-0.03749999999999998)

# %%
print (arr2.mean())
print (arr2.mean(0))
print (arr2.mean(1))
print(arr2[0])
print(arr2[1])
print(arr2.mean[0][:2])
# Out:
# 0.5999999999999999
# [ 0.25   0.715  2.335 -0.9  ]
# [-0.0375  1.2375]
# [ 1.    1.1  -5.45  3.2 ]
# [-0.5   0.33 10.12 -5.  ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 print(arr2[0])
#       5 print(arr2[1])
# ----> 6 print(arr2.mean[0][:2])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
# you can call these functions using top-level numpy functions too
np.mean(arr2)
# Out:
# 0.5999999999999999

# %%
# some functions don't aggregate but instead produce an array
arr2.cumsum(0)
# Out:
# array([[ 1.  ,  1.1 , -5.45,  3.2 ],
#        [ 0.5 ,  1.43,  4.67, -1.8 ]])

# %%
arr2
# Out:
# array([[ 1.  ,  1.1 , -5.45,  3.2 ],
#        [-0.5 ,  0.33, 10.12, -5.  ]])

# %% [markdown]
# #### More Array Methods:
# ![Screen%20Shot%202021-10-17%20at%207.39.38%20PM.png](attachment:Screen%20Shot%202021-10-17%20at%207.39.38%20PM.png)

# %% [markdown]
# ### Boolean Array Operations

# %%
mask=(arr1>0)
mask

# %%
mask.sum()

# %%
mask.mean()

# %%
mask.any()

# %%
mask.all()

# %% [markdown]
# ### Sorting/Unique Values

# %%
arr1

# %%
# sort an array in place
arr1.sort()
arr1

# %%
# get unique values in sorted order
tickers=np.array(['Tech','Tech','Cons','Energy','Financials','Financials'])
np.unique(tickers)
